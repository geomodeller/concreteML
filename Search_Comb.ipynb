# %%
import pandas as pd
import itertools
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
def evaluate_all_combinations_cv(X, y):
    results = []
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    for r in range(1, len(X.columns) + 1):
        for combo in itertools.combinations(X.columns, r):
            X_subset = X[list(combo)]
            model = LinearRegression()
            scores = cross_val_score(model, X_subset, y, cv=kf, scoring='r2')
            mean_r2 = scores.mean()
            results.append({
                'num_features': r,
                'features': combo,
                'mean_r2': mean_r2
            })

    # 결과를 정렬
    results_df = pd.DataFrame(results).sort_values(by='mean_r2', ascending=False).reset_index(drop=True)

    # 결과 전체 출력
    for i, row in results_df.iterrows():
        print(f"{i+1}. Features: {row['features']}, R²: {row['mean_r2']:.4f}")

    # 최고 조합 반환
    best = results_df.iloc[0]
    return best['features'], best['mean_r2'], results_df

# %%
df = pd.read_csv('dataset.csv')  

# X, y 설정 (
X = df[['cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age']]
y = df['CCS']


best_combo, best_r2, all_results = evaluate_all_combinations_cv(X, y)

print("\n📌 최고 조합:", best_combo)
print("📈 최고 평균 결정계수(R²):", best_r2)

# 필요한 경우 엑셀로 저장
all_results.to_csv("모든_조합_결정계수.csv", index=False)
# Out:
# 1. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.6007
# 2. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'age'), R²: 0.6007
# 3. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.6003
# 4. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.6001
# 5. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'age'), R²: 0.6000
# 6. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'fine aggregate', 'age'), R²: 0.5999
# 7. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'coarse aggregate', 'age'), R²: 0.5990
# 8. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5989
# 9. Features: ('cement', 'blast furnace slag', 'fly ash', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5971
# 10. Features: ('cement', 'blast furnace slag', 'fly ash', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5842
# 11. Features: ('cement', 'blast furnace slag', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5830
# 12. Features: ('cement', 'blast furnace slag', 'water ', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5788
# 13. Features: ('cement', 'blast furnace slag', 'water ', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.5787
# 14. Features: ('cement', 'blast furnace slag', 'water ', 'superplasticizer', 'age'), R²: 0.5754
# 15. Features: ('cement', 'blast furnace slag', 'water ', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.5751
# 16. Features: ('cement', 'blast furnace slag', 'fly ash', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.5704
# 17. Features: ('cement', 'blast furnace slag', 'fly ash', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.5701
# 18. Features: ('cement', 'blast furnace slag', 'fly ash', 'superplasticizer', 'age'), R²: 0.5616
# 19. Features: ('cement', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5615
# 20. Features: ('cement', 'fly ash', 'water ', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5605
# 21. Features: ('cement', 'water ', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5602
# 22. Features: ('cement', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5594
# 23. Features: ('cement', 'blast furnace slag', 'water ', 'coarse aggregate', 'age'), R²: 0.5565
# 24. Features: ('cement', 'blast furnace slag', 'water ', 'fine aggregate', 'age'), R²: 0.5541
# 25. Features: ('cement', 'blast furnace slag', 'water ', 'age'), R²: 0.5492
# 26. Features: ('cement', 'blast furnace slag', 'fly ash', 'fine aggregate', 'age'), R²: 0.5490
# 27. Features: ('cement', 'blast furnace slag', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.5488
# 28. Features: ('cement', 'blast furnace slag', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5476
# 29. Features: ('cement', 'blast furnace slag', 'superplasticizer', 'age'), R²: 0.5440
# 30. Features: ('cement', 'blast furnace slag', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.5420
# 31. Features: ('blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5248
# 32. Features: ('blast furnace slag', 'fly ash', 'water ', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5240
# 33. Features: ('cement', 'fly ash', 'water ', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.5230
# 34. Features: ('cement', 'water ', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.5222
# 35. Features: ('fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5170
# 36. Features: ('fly ash', 'water ', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.5161
# 37. Features: ('cement', 'blast furnace slag', 'fly ash', 'coarse aggregate', 'age'), R²: 0.5109
# 38. Features: ('cement', 'blast furnace slag', 'fly ash', 'age'), R²: 0.5084
# 39. Features: ('cement', 'water ', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.4998
# 40. Features: ('cement', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.4964
# 41. Features: ('cement', 'water ', 'superplasticizer', 'age'), R²: 0.4926
# 42. Features: ('cement', 'fly ash', 'water ', 'superplasticizer', 'age'), R²: 0.4889
# 43. Features: ('cement', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.4872
# 44. Features: ('cement', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.4865
# 45. Features: ('cement', 'fly ash', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.4851
# 46. Features: ('cement', 'water ', 'fine aggregate', 'age'), R²: 0.4848
# 47. Features: ('cement', 'fly ash', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.4845
# 48. Features: ('water ', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.4834
# 49. Features: ('cement', 'water ', 'coarse aggregate', 'age'), R²: 0.4813
# 50. Features: ('blast furnace slag', 'water ', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.4808
# 51. Features: ('water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.4798
# 52. Features: ('cement', 'fly ash', 'water ', 'fine aggregate', 'age'), R²: 0.4798
# 53. Features: ('cement', 'superplasticizer', 'age'), R²: 0.4781
# 54. Features: ('cement', 'fly ash', 'water ', 'coarse aggregate', 'age'), R²: 0.4776
# 55. Features: ('blast furnace slag', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.4770
# 56. Features: ('cement', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.4767
# 57. Features: ('cement', 'fly ash', 'superplasticizer', 'age'), R²: 0.4740
# 58. Features: ('cement', 'fly ash', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.4729
# 59. Features: ('fly ash', 'water ', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.4517
# 60. Features: ('blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.4498
# 61. Features: ('cement', 'water ', 'age'), R²: 0.4464
# 62. Features: ('cement', 'fly ash', 'water ', 'age'), R²: 0.4425
# 63. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer'), R²: 0.4278
# 64. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate'), R²: 0.4273
# 65. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'fine aggregate'), R²: 0.4272
# 66. Features: ('cement', 'blast furnace slag', 'fly ash', 'water '), R²: 0.4268
# 67. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.4265
# 68. Features: ('cement', 'blast furnace slag', 'fly ash', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.4265
# 69. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'fine aggregate'), R²: 0.4251
# 70. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'coarse aggregate'), R²: 0.4249
# 71. Features: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'coarse aggregate', 'fine aggregate'), R²: 0.4245
# 72. Features: ('cement', 'blast furnace slag', 'fly ash', 'superplasticizer', 'coarse aggregate'), R²: 0.4227
# 73. Features: ('cement', 'blast furnace slag', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.4210
# 74. Features: ('cement', 'blast furnace slag', 'fly ash', 'superplasticizer'), R²: 0.4190
# 75. Features: ('cement', 'blast furnace slag', 'water ', 'superplasticizer', 'fine aggregate'), R²: 0.4190
# 76. Features: ('cement', 'blast furnace slag', 'fly ash', 'superplasticizer', 'fine aggregate'), R²: 0.4188
# 77. Features: ('cement', 'blast furnace slag', 'water ', 'coarse aggregate', 'fine aggregate'), R²: 0.4173
# 78. Features: ('cement', 'blast furnace slag', 'water ', 'superplasticizer'), R²: 0.4148
# 79. Features: ('cement', 'blast furnace slag', 'water ', 'superplasticizer', 'coarse aggregate'), R²: 0.4141
# 80. Features: ('cement', 'blast furnace slag', 'fine aggregate', 'age'), R²: 0.4140
# 81. Features: ('cement', 'blast furnace slag', 'fly ash', 'coarse aggregate', 'fine aggregate'), R²: 0.4137
# 82. Features: ('cement', 'blast furnace slag', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.4116
# 83. Features: ('cement', 'blast furnace slag', 'superplasticizer', 'coarse aggregate'), R²: 0.4107
# 84. Features: ('cement', 'blast furnace slag', 'superplasticizer'), R²: 0.4089
# 85. Features: ('cement', 'blast furnace slag', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.4087
# 86. Features: ('cement', 'blast furnace slag', 'superplasticizer', 'fine aggregate'), R²: 0.4075
# 87. Features: ('blast furnace slag', 'water ', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.4068
# 88. Features: ('cement', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.4043
# 89. Features: ('cement', 'blast furnace slag', 'age'), R²: 0.4036
# 90. Features: ('cement', 'fly ash', 'water ', 'coarse aggregate', 'fine aggregate'), R²: 0.4031
# 91. Features: ('cement', 'blast furnace slag', 'coarse aggregate', 'age'), R²: 0.4016
# 92. Features: ('water ', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.4013
# 93. Features: ('cement', 'water ', 'coarse aggregate', 'fine aggregate'), R²: 0.4011
# 94. Features: ('cement', 'blast furnace slag', 'fly ash', 'fine aggregate'), R²: 0.4006
# 95. Features: ('cement', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.3996
# 96. Features: ('cement', 'blast furnace slag', 'water ', 'fine aggregate'), R²: 0.3970
# 97. Features: ('cement', 'blast furnace slag', 'water ', 'coarse aggregate'), R²: 0.3956
# 98. Features: ('cement', 'blast furnace slag', 'water '), R²: 0.3916
# 99. Features: ('blast furnace slag', 'fly ash', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.3895
# 100. Features: ('fly ash', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.3893
# 101. Features: ('fly ash', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.3871
# 102. Features: ('cement', 'blast furnace slag', 'fly ash', 'coarse aggregate'), R²: 0.3870
# 103. Features: ('cement', 'blast furnace slag', 'fly ash'), R²: 0.3869
# 104. Features: ('blast furnace slag', 'fly ash', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.3857
# 105. Features: ('blast furnace slag', 'fly ash', 'water ', 'fine aggregate', 'age'), R²: 0.3851
# 106. Features: ('fly ash', 'water ', 'fine aggregate', 'age'), R²: 0.3834
# 107. Features: ('blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.3815
# 108. Features: ('fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.3803
# 109. Features: ('cement', 'fly ash', 'water ', 'superplasticizer', 'fine aggregate'), R²: 0.3753
# 110. Features: ('cement', 'water ', 'superplasticizer', 'fine aggregate'), R²: 0.3720
# 111. Features: ('blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'age'), R²: 0.3720
# 112. Features: ('blast furnace slag', 'water ', 'fine aggregate', 'age'), R²: 0.3715
# 113. Features: ('fly ash', 'water ', 'superplasticizer', 'age'), R²: 0.3674
# 114. Features: ('blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.3670
# 115. Features: ('blast furnace slag', 'fly ash', 'water ', 'coarse aggregate', 'fine aggregate'), R²: 0.3659
# 116. Features: ('cement', 'fly ash', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.3628
# 117. Features: ('cement', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.3624
# 118. Features: ('water ', 'fine aggregate', 'age'), R²: 0.3620
# 119. Features: ('cement', 'fly ash', 'superplasticizer', 'fine aggregate'), R²: 0.3612
# 120. Features: ('cement', 'superplasticizer', 'fine aggregate'), R²: 0.3609
# 121. Features: ('blast furnace slag', 'water ', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.3528
# 122. Features: ('blast furnace slag', 'fly ash', 'water ', 'coarse aggregate', 'age'), R²: 0.3492
# 123. Features: ('cement', 'fly ash', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.3489
# 124. Features: ('cement', 'fly ash', 'coarse aggregate', 'age'), R²: 0.3486
# 125. Features: ('fly ash', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.3474
# 126. Features: ('fly ash', 'superplasticizer', 'age'), R²: 0.3470
# 127. Features: ('blast furnace slag', 'fly ash', 'superplasticizer', 'age'), R²: 0.3469
# 128. Features: ('blast furnace slag', 'fly ash', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.3466
# 129. Features: ('fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.3465
# 130. Features: ('fly ash', 'water ', 'coarse aggregate', 'age'), R²: 0.3451
# 131. Features: ('fly ash', 'water ', 'coarse aggregate', 'fine aggregate'), R²: 0.3451
# 132. Features: ('cement', 'water ', 'superplasticizer', 'coarse aggregate'), R²: 0.3437
# 133. Features: ('cement', 'superplasticizer'), R²: 0.3428
# 134. Features: ('blast furnace slag', 'water ', 'superplasticizer', 'age'), R²: 0.3426
# 135. Features: ('cement', 'superplasticizer', 'coarse aggregate'), R²: 0.3421
# 136. Features: ('blast furnace slag', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.3414
# 137. Features: ('superplasticizer', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.3413
# 138. Features: ('cement', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate'), R²: 0.3411
# 139. Features: ('cement', 'water ', 'superplasticizer'), R²: 0.3408
# 140. Features: ('cement', 'fly ash', 'superplasticizer'), R²: 0.3397
# 141. Features: ('cement', 'fly ash', 'superplasticizer', 'coarse aggregate'), R²: 0.3394
# 142. Features: ('blast furnace slag', 'superplasticizer', 'fine aggregate', 'age'), R²: 0.3388
# 143. Features: ('cement', 'fly ash', 'age'), R²: 0.3388
# 144. Features: ('cement', 'water ', 'fine aggregate'), R²: 0.3384
# 145. Features: ('cement', 'fly ash', 'water ', 'superplasticizer'), R²: 0.3381
# 146. Features: ('cement', 'fly ash', 'fine aggregate', 'age'), R²: 0.3381
# 147. Features: ('blast furnace slag', 'water ', 'coarse aggregate', 'age'), R²: 0.3377
# 148. Features: ('water ', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.3374
# 149. Features: ('cement', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.3369
# 150. Features: ('superplasticizer', 'fine aggregate', 'age'), R²: 0.3368
# 151. Features: ('cement', 'coarse aggregate', 'age'), R²: 0.3364
# 152. Features: ('cement', 'fly ash', 'water ', 'fine aggregate'), R²: 0.3338
# 153. Features: ('cement', 'water ', 'coarse aggregate'), R²: 0.3257
# 154. Features: ('cement', 'age'), R²: 0.3255
# 155. Features: ('cement', 'fine aggregate', 'age'), R²: 0.3248
# 156. Features: ('water ', 'coarse aggregate', 'age'), R²: 0.3229
# 157. Features: ('cement', 'fly ash', 'water ', 'coarse aggregate'), R²: 0.3207
# 158. Features: ('water ', 'superplasticizer', 'age'), R²: 0.3187
# 159. Features: ('cement', 'blast furnace slag', 'fine aggregate'), R²: 0.3166
# 160. Features: ('cement', 'blast furnace slag'), R²: 0.3156
# 161. Features: ('cement', 'blast furnace slag', 'coarse aggregate', 'fine aggregate'), R²: 0.3149
# 162. Features: ('cement', 'blast furnace slag', 'coarse aggregate'), R²: 0.3140
# 163. Features: ('blast furnace slag', 'superplasticizer', 'age'), R²: 0.3124
# 164. Features: ('blast furnace slag', 'superplasticizer', 'coarse aggregate', 'age'), R²: 0.3121
# 165. Features: ('blast furnace slag', 'fly ash', 'water ', 'age'), R²: 0.3020
# 166. Features: ('superplasticizer', 'coarse aggregate', 'age'), R²: 0.3000
# 167. Features: ('cement', 'water '), R²: 0.2995
# 168. Features: ('blast furnace slag', 'water ', 'coarse aggregate', 'fine aggregate'), R²: 0.2986
# 169. Features: ('superplasticizer', 'age'), R²: 0.2983
# 170. Features: ('water ', 'coarse aggregate', 'fine aggregate'), R²: 0.2981
# 171. Features: ('blast furnace slag', 'water ', 'age'), R²: 0.2979
# 172. Features: ('cement', 'fly ash', 'water '), R²: 0.2941
# 173. Features: ('blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'fine aggregate'), R²: 0.2926
# 174. Features: ('blast furnace slag', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.2924
# 175. Features: ('water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.2924
# 176. Features: ('fly ash', 'water ', 'superplasticizer', 'fine aggregate'), R²: 0.2914
# 177. Features: ('fly ash', 'water ', 'age'), R²: 0.2807
# 178. Features: ('blast furnace slag', 'fly ash', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.2720
# 179. Features: ('water ', 'age'), R²: 0.2639
# 180. Features: ('fly ash', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.2639
# 181. Features: ('blast furnace slag', 'fly ash', 'superplasticizer', 'fine aggregate'), R²: 0.2610
# 182. Features: ('fly ash', 'superplasticizer', 'fine aggregate'), R²: 0.2583
# 183. Features: ('cement', 'fly ash', 'coarse aggregate', 'fine aggregate'), R²: 0.2583
# 184. Features: ('cement', 'coarse aggregate', 'fine aggregate'), R²: 0.2562
# 185. Features: ('cement', 'fly ash', 'coarse aggregate'), R²: 0.2529
# 186. Features: ('cement', 'coarse aggregate'), R²: 0.2506
# 187. Features: ('cement', 'fly ash', 'fine aggregate'), R²: 0.2442
# 188. Features: ('cement', 'fly ash'), R²: 0.2425
# 189. Features: ('cement', 'fine aggregate'), R²: 0.2412
# 190. Features: ('cement',), R²: 0.2395
# 191. Features: ('blast furnace slag', 'water ', 'superplasticizer', 'fine aggregate'), R²: 0.2247
# 192. Features: ('water ', 'superplasticizer', 'fine aggregate'), R²: 0.2238
# 193. Features: ('fly ash', 'water ', 'fine aggregate'), R²: 0.2222
# 194. Features: ('blast furnace slag', 'fly ash', 'water ', 'fine aggregate'), R²: 0.2203
# 195. Features: ('fly ash', 'water ', 'superplasticizer', 'coarse aggregate'), R²: 0.2043
# 196. Features: ('blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate'), R²: 0.2029
# 197. Features: ('superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.2017
# 198. Features: ('blast furnace slag', 'superplasticizer', 'coarse aggregate', 'fine aggregate'), R²: 0.2004
# 199. Features: ('fly ash', 'superplasticizer', 'coarse aggregate'), R²: 0.1987
# 200. Features: ('fly ash', 'water ', 'superplasticizer'), R²: 0.1969
# 201. Features: ('blast furnace slag', 'fly ash', 'superplasticizer', 'coarse aggregate'), R²: 0.1969
# 202. Features: ('fly ash', 'superplasticizer'), R²: 0.1969
# 203. Features: ('blast furnace slag', 'fly ash', 'water ', 'superplasticizer'), R²: 0.1968
# 204. Features: ('blast furnace slag', 'fly ash', 'superplasticizer'), R²: 0.1956
# 205. Features: ('superplasticizer', 'fine aggregate'), R²: 0.1924
# 206. Features: ('blast furnace slag', 'water ', 'fine aggregate'), R²: 0.1921
# 207. Features: ('blast furnace slag', 'superplasticizer', 'fine aggregate'), R²: 0.1919
# 208. Features: ('water ', 'fine aggregate'), R²: 0.1887
# 209. Features: ('fly ash', 'water ', 'coarse aggregate'), R²: 0.1651
# 210. Features: ('blast furnace slag', 'fly ash', 'water ', 'coarse aggregate'), R²: 0.1646
# 211. Features: ('blast furnace slag', 'water ', 'superplasticizer', 'coarse aggregate'), R²: 0.1530
# 212. Features: ('coarse aggregate', 'fine aggregate', 'age'), R²: 0.1501
# 213. Features: ('blast furnace slag', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.1487
# 214. Features: ('fly ash', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.1471
# 215. Features: ('blast furnace slag', 'water ', 'superplasticizer'), R²: 0.1465
# 216. Features: ('blast furnace slag', 'fly ash', 'coarse aggregate', 'fine aggregate', 'age'), R²: 0.1452
# 217. Features: ('blast furnace slag', 'superplasticizer', 'coarse aggregate'), R²: 0.1444
# 218. Features: ('blast furnace slag', 'superplasticizer'), R²: 0.1434
# 219. Features: ('water ', 'superplasticizer', 'coarse aggregate'), R²: 0.1431
# 220. Features: ('blast furnace slag', 'water ', 'coarse aggregate'), R²: 0.1400
# 221. Features: ('blast furnace slag', 'coarse aggregate', 'age'), R²: 0.1368
# 222. Features: ('superplasticizer', 'coarse aggregate'), R²: 0.1360
# 223. Features: ('blast furnace slag', 'fly ash', 'coarse aggregate', 'age'), R²: 0.1326
# 224. Features: ('coarse aggregate', 'age'), R²: 0.1323
# 225. Features: ('superplasticizer',), R²: 0.1317
# 226. Features: ('water ', 'coarse aggregate'), R²: 0.1307
# 227. Features: ('water ', 'superplasticizer'), R²: 0.1307
# 228. Features: ('fly ash', 'coarse aggregate', 'age'), R²: 0.1302
# 229. Features: ('blast furnace slag', 'fine aggregate', 'age'), R²: 0.1243
# 230. Features: ('blast furnace slag', 'age'), R²: 0.1203
# 231. Features: ('blast furnace slag', 'fly ash', 'water '), R²: 0.1199
# 232. Features: ('blast furnace slag', 'fly ash', 'fine aggregate', 'age'), R²: 0.1195
# 233. Features: ('fine aggregate', 'age'), R²: 0.1161
# 234. Features: ('blast furnace slag', 'fly ash', 'age'), R²: 0.1153
# 235. Features: ('fly ash', 'fine aggregate', 'age'), R²: 0.1123
# 236. Features: ('fly ash', 'water '), R²: 0.1100
# 237. Features: ('blast furnace slag', 'water '), R²: 0.1058
# 238. Features: ('age',), R²: 0.1058
# 239. Features: ('fly ash', 'age'), R²: 0.1029
# 240. Features: ('water ',), R²: 0.0820
# 241. Features: ('fly ash', 'coarse aggregate', 'fine aggregate'), R²: 0.0637
# 242. Features: ('blast furnace slag', 'fly ash', 'coarse aggregate', 'fine aggregate'), R²: 0.0618
# 243. Features: ('coarse aggregate', 'fine aggregate'), R²: 0.0618
# 244. Features: ('blast furnace slag', 'coarse aggregate', 'fine aggregate'), R²: 0.0595
# 245. Features: ('fly ash', 'coarse aggregate'), R²: 0.0317
# 246. Features: ('blast furnace slag', 'fly ash', 'coarse aggregate'), R²: 0.0307
# 247. Features: ('blast furnace slag', 'coarse aggregate'), R²: 0.0300
# 248. Features: ('blast furnace slag', 'fine aggregate'), R²: 0.0272
# 249. Features: ('coarse aggregate',), R²: 0.0265
# 250. Features: ('blast furnace slag', 'fly ash', 'fine aggregate'), R²: 0.0254
# 251. Features: ('fly ash', 'fine aggregate'), R²: 0.0244
# 252. Features: ('fine aggregate',), R²: 0.0233
# 253. Features: ('blast furnace slag',), R²: 0.0119
# 254. Features: ('blast furnace slag', 'fly ash'), R²: 0.0098
# 255. Features: ('fly ash',), R²: 0.0033
#
# 📌 최고 조합: ('cement', 'blast furnace slag', 'fly ash', 'water ', 'superplasticizer', 'coarse aggregate', 'fine aggregate', 'age')
# 📈 최고 평균 결정계수(R²): 0.6006959620275698
